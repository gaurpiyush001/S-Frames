# %%
import graphlab

# %%
sales = graphlab.SFrame('D:\house_data11\home_data.sframe')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to gaurpiyush001@gmail.com and will expire on May 28, 2021.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\gaura\AppData\Local\Temp\graphlab_server_1594825933.log.0

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %%
graphlab.canvas.set_target('ipynb')
sales.show(view='Scatter Plot', x='sqft_living', y='price')

# %%
train_data,test_data = sales.random_split(.8,seed=0)

# %%
sale_model = graphlab.linear_regression.create(train_data,target='price',
                                              features=['sqft_living'],
                                              validation_set=None,
                                              verbose=False)

# %%
sale_model.get('coefficients')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+----------------+---------------+
# |     name    | index |     value      |     stderr    |
# +-------------+-------+----------------+---------------+
# | (intercept) |  None | -47114.0206702 | 4923.34437753 |
# | sqft_living |  None | 281.957850166  | 2.16405465323 |
# +-------------+-------+----------------+---------------+
# [2 rows x 4 columns]

# %%
sale_model.evaluate(test_data)
# Out:
# {'max_error': 4143550.8825285938, 'rmse': 255191.02870527355}

# %%
sales.show(view='Scatter Plot', x = test_data['sqft_living'], y = sqft_model.predict(test_data), '-')
# Out:
#   File "<ipython-input-10-ac45777f5c93>", line 1
#     sales.show(view='Scatter Plot', x = test_data['sqft_living'], y = sqft_model.predict(test_data), '-')
# SyntaxError: non-keyword arg after keyword arg

# %%
house1 = sales[sales['sqft_living']=='2650']

# %%
house1
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# 	[]

# %%
sale_model.predict(house1)
# Out:
# [ERROR] graphlab.toolkits._main: Toolkit error: Input data does not contain any rows.
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-13-f0547c5ad632> in <module>()
# ----> 1 sale_model.predict(house1)
#
# c:\devl\gllab\lib\site-packages\graphlab\toolkits\regression\linear_regression.pyc in predict(self, dataset, missing_value_action)
#     590
#     591         _mt._get_metric_tracker().track('toolkit.regression.linear_regression.predict')
# --> 592         return super(LinearRegression, self).predict(dataset, missing_value_action=missing_value_action)
#     593
#     594     @_collect_model_workflow
#
# c:\devl\gllab\lib\site-packages\graphlab\toolkits\_supervised_learning.pyc in predict(self, dataset, missing_value_action, output_type, options, **kwargs)
#     135
#     136             target = _graphlab.toolkits._main.run(
# ...

# %%
sale_model.evaluate(train_data)
# Out:
# {'max_error': 4349521.9261700595, 'rmse': 262943.6137536492}
